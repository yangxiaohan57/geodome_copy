# %% [markdown]
# # Earth Engine for gathering data
#
# Google Earth Engine is a powerful tool for geospatial data analysis. Here, we will discuss how to use its Python API for gathering data from Landsat, Sentinel, and NAIP imagery.
#
# To start off with, request access to Google Earth Engine at: [](https://earthengine.google.com/). This may take some time. Once approved, install the Python API and get credentials for using the API following [these instructions](https://developers.google.com/earth-engine/guides/python_install-conda#mac_6). Be sure to try out the test code they suggest to make sure Earth Engine is running successfully):

# %%
import numpy as np
import zipfile
import rasterio
import matplotlib.pyplot as plt

# %%
import ee

# Initialize the Earth Engine module.
ee.Initialize()

# %% [markdown]
# If the above code yields output, you'll know you're ready for to go!
#
# ## Selecting imagery

# %%
from geetools import batch

def download_S2_toLocal(bbox, name, scale=1):
    """
    downloads Sentinel 2 imagery from the specified bounding box and saves it as `name`
    """
    AOI = ee.Geometry.Rectangle(list(bbox), "EPSG:4326", False)

    collection = (
        ee.ImageCollection("COPERNICUS/S2_SR")
        .filterDate('2020-10-01', '2020-10-10')
        .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE',20))
        .filterBounds(AOI)
        .select(['B2', 'B3', 'B4'])
    )

    image = ee.Image(collection.mosaic()).clip(AOI)
    batch.image.toLocal(image, name, scale=scale, region=AOI)
    return collection

# center of image (base of plant)
x = 33.6319
y = -87.0597

# lat long of image
# will vary based on the surface of the earth
lat = [x-0.004, x+0.004]
lon = [y-0.004, y+0.004]
bbox = [lon[0], lat[0], lon[1], lat[1]]
name = 's2sample'
image = download_S2_toLocal(bbox, name, scale=1)

# %%
path_to_zip_file = 's2sample.zip'
directory_to_extract_to = 's2sample'
with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
    zip_ref.extractall(directory_to_extract_to)

# %%
def stack_bands_s2(name, outname):
    file_list = [name + '.B4.tif', name + '.B3.tif', name + '.B2.tif']

    # Read metadata of first file
    with rasterio.open(file_list[0]) as src0:
        meta = src0.meta

    # Update meta to reflect the number of layers
    meta.update(count = len(file_list))

    # Read each layer and write it to stack
    with rasterio.open(outname, 'w', **meta) as dst:
        for id, layer in enumerate(file_list, start=1):
            with rasterio.open(layer) as src1:
                dst.write_band(id, src1.read(1))

outname = "stacked_s2_sample.tif"
stack_bands_s2('s2sample/download',outname)

# %%
# Plot the example
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
from rasterio.plot import show

fig, ax = plt.subplots(num='main', figsize=(10,10))

from rasterio.plot import show
data = rasterio.open(outname)

# show(data.read([1,2,3]).astype('float')/4096, transform=data.transform, ax=ax)
show(data.read([1,2,3]).astype('float')/4096, transform=data.transform, ax=ax)
plt.savefig(r'miller.jpg')

# show(data.read([1,2,3]).astype('float')/255, transform=data.transform, ax=ax)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Load Image as NumPy Array

# %%
# load image as numpy array
with rasterio.open('stacked_s2_sample.tif') as ds:
    img_arr = ds.read()  # read all raster values

# %%
# try numpy swap axis, use this --> *move axis, roll axis
img_arr = np.moveaxis(img_arr, 0, -1)
img_arr = img_arr/4095
fig, ax = plt.subplots(num='main', figsize=(10,10))
plt.axis('off')
plt.imshow(img_arr, aspect = 'auto')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Convert image to grayscale?

# %%
# take average of each band -- create grayscale image
img_arr_bw = np.average(img_arr, weights=[0.1140, 0.5870, 0.2989], axis=2)

# %%
img_arr_bw.shape
# Out:
# (892, 891)

# %%
# true color of averaged image?
fig, ax = plt.subplots(num='main', figsize=(10,10))
plt.axis('off')
plt.imshow(img_arr_bw, aspect = 'auto', cmap ='gray')
plt.scatter(891/2,892/2, c='red', s=30)
plt.show()

# %%
# select threshold
img_seg = np.where(img_arr_bw < 0.24, 0, 1)

# %%
fig, ax = plt.subplots(num='main', figsize=(10,10))
plt.axis('off')
plt.imshow(img_seg, aspect = 'auto', cmap ='gray')
plt.scatter(891/2,892/2, c='red', s=30)
plt.show()

# %% [markdown]
# #### Crop Image

# %%
img_seg.shape
# Out:
# (892, 891)

# %%
img_seg_crop = img_seg[215:446, 300:447]

# %%
img_seg_crop.shape
# Out:
# (231, 147)

# %%
# plt.figure(figsize=(10, 10))
plt.imshow(img_seg_crop)
plt.scatter(147, 231, c='red', s=20)
plt.imsave('img_seg_crop.jpg', img_seg_crop)
plt.show()

# %% [markdown]
# ## Connected components (Gaussian Filtering + Connected Components)
#
# **Note: Ignore gaussian filtering when image is only 1s & 0s)

# %%
from PIL import Image
from scipy import ndimage

# %%
blur_radius = 0.1
threshold = 0.25

# %%
# smooth the image (to remove small objects)
# imgf = ndimage.gaussian_filter(img_seg_crop, blur_radius)

# %%
threshold = 0.5

# find connected components
labeled, nr_objects = ndimage.label(img_seg_crop > threshold) 
print("Number of objects is {}".format(nr_objects))
# Out:
# Number of objects is 1

# %%
plt.imshow(labeled)
plt.show()

# %%
# try for dark color variations
img_seg_dark = np.where(img_arr_bw_norm > 0.24, 0, img_arr_bw_norm)
img_seg_crop_dark = img_seg[215:446, 300:447]

plt.imshow(img_seg_crop_dark)
plt.scatter(147, 231, c='red', s=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-ee197ccac28f> in <module>
#       1 # try for dark color variations
# ----> 2 img_seg_dark = np.where(img_arr_bw_norm > 0.24, 0, img_arr_bw_norm)
#       3 img_seg_crop_dark = img_seg[215:446, 300:447]
#       4
#       5 plt.imshow(img_seg_crop_dark)
#
# NameError: name 'img_arr_bw_norm' is not defined

# %%
blur_radius = 0.1
threshold = 0.10

# smooth the image (to remove small objects)
imgf = ndimage.gaussian_filter(img_seg_crop_dark, blur_radius)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-33fa1baa9acc> in <module>
#       3
#       4 # smooth the image (to remove small objects)
# ----> 5 imgf = ndimage.gaussian_filter(img_seg_crop_dark, blur_radius)
#
# NameError: name 'img_seg_crop_dark' is not defined

# %%
# find connected components
labeled, nr_objects = ndimage.label(imgf > threshold) 
print("Number of objects is {}".format(nr_objects))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-3cab5da13fa4> in <module>
#       1 # find connected components
# ----> 2 labeled, nr_objects = ndimage.label(imgf > threshold)
#       3 print("Number of objects is {}".format(nr_objects))
#
# NameError: name 'imgf' is not defined

# %%
# look at potential angle range
# key point detection
plt.imshow(labeled)
plt.show()

# %% [markdown]
# ## Segment shadow in image with k-means clustering

# %%
import cv2

# %%
img_arr_transpose = np.transpose(img_arr)/2000

# %%
plt.figure(figsize=(10, 10))
plt.imshow(img_arr_transpose/2000)
plt.scatter(892/2,891/2, c='red', s=100)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-874baec3b312> in <module>
#       1 plt.figure(figsize=(10, 10))
# ----> 2 plt.imshow(img_arr_transpose/2000)
#       3 plt.scatter(892/2,891/2, c='red', s=100)
#       4 plt.show()
#
# ~/opt/anaconda3/envs/capstone/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2728         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2729         url=url, **({"data": data} if data is not None else {}),
# -> 2730         **kwargs)
#    2731     sci(__ret)
#    2732     return __ret
#
# ~/opt/anaconda3/envs/capstone/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/envs/capstone/lib/python3.6/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# ~/opt/anaconda3/envs/capstone/lib/python3.6/site-packages/matplotlib/image.py in set_data(self, A)
#     710                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
#     711             raise TypeError("Invalid shape {} for image data"
# --> 712                             .format(self._A.shape))
#     713
#     714         if self._A.ndim == 3:
#
# TypeError: Invalid shape (3, 891, 892) for image data

# %%
img_arr_transpose_crop = img_arr_transpose[250:500, 150:500]

# %%
# normalize by largest value in array
img_arr_transpose_norm = img_arr_transpose_crop/img_arr_transpose_crop.max()
img_arr_transpose_seg = np.where(img_arr_transpose_norm > 0.24, 0, img_arr_transpose_norm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-38de07a06f51> in <module>
#       1 # normalize by largest value in array
# ----> 2 img_arr_transpose_norm = img_arr_transpose_crop/img_arr_transpose_crop.max()
#       3 img_arr_transpose_seg = np.where(img_arr_transpose_norm > 0.24, 0, img_arr_transpose_norm)
#
# NameError: name 'img_arr_transpose_crop' is not defined

# %%
img=cv2.cvtColor(img_arr_transpose_crop,cv2.COLOR_BGR2RGB)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-0a88ed54d45a> in <module>
# ----> 1 img=cv2.cvtColor(img_arr_transpose_crop,cv2.COLOR_BGR2RGB)
#
# NameError: name 'img_arr_transpose_crop' is not defined

# %%
# vectorized = img_arr_transpose_seg.reshape((-1,3))
vectorized = img.reshape((-1,3))
vectorized = np.float32(vectorized)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-2e3f70997c57> in <module>
#       1 # vectorized = img_arr_transpose_seg.reshape((-1,3))
# ----> 2 vectorized = img.reshape((-1,3))
#       3 vectorized = np.float32(vectorized)
#
# NameError: name 'img' is not defined

# %%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)

# %%
K = 3
attempts=10
ret,label,center=cv2.kmeans(vectorized,K,None,criteria,attempts,cv2.KMEANS_PP_CENTERS)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-82648a32fd8a> in <module>
#       1 K = 3
#       2 attempts=10
# ----> 3 ret,label,center=cv2.kmeans(vectorized,K,None,criteria,attempts,cv2.KMEANS_PP_CENTERS)
#
# NameError: name 'vectorized' is not defined

# %%
center = np.uint8(center)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-40ce97a9b0a0> in <module>
# ----> 1 center = np.uint8(center)
#
# NameError: name 'center' is not defined

# %%
res = center[label.flatten()]
result_image = res.reshape((img.shape))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-3fdd448366be> in <module>
# ----> 1 res = center[label.flatten()]
#       2 result_image = res.reshape((img.shape))
#
# NameError: name 'center' is not defined

# %%
figure_size = 15
plt.figure(figsize=(figure_size,figure_size))
plt.subplot(1,2,1),plt.imshow(img/4095)
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(1,2,2),plt.imshow(result_image)
plt.title('Segmented Image when K = %i' % K), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-756595337314> in <module>
#       1 figure_size = 15
#       2 plt.figure(figsize=(figure_size,figure_size))
# ----> 3 plt.subplot(1,2,1),plt.imshow(img/4095)
#       4 plt.title('Original Image'), plt.xticks([]), plt.yticks([])
#       5 plt.subplot(1,2,2),plt.imshow(result_image)
#
# NameError: name 'img' is not defined

# %%
#scikit image

# %% [markdown]
# ## Mean-shift shadow segmentation
